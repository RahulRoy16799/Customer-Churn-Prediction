# %%
import pandas as pd

# %%
df = pd.read_csv('customer_churn_data.csv')
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4             NaN       2208.32          No   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1000 non-null   int64
#  1   Age              1000 non-null   int64
#  2   Gender           1000 non-null   object
#  3   Tenure           1000 non-null   int64
#  4   MonthlyCharges   1000 non-null   float64
#  5   ContractType     1000 non-null   object
#  6   InternetService  703 non-null    object
#  7   TotalCharges     1000 non-null   float64
#  8   TechSupport      1000 non-null   object
#  9   Churn            1000 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.3+ KB

# %%
#Checking null values
df.isna().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %%
#Fixing the null values
df["InternetService"] = df["InternetService"].fillna("")

# %%
df.isna().sum()
# Out:
# CustomerID         0
# Age                0
# Gender             0
# Tenure             0
# MonthlyCharges     0
# ContractType       0
# InternetService    0
# TotalCharges       0
# TechSupport        0
# Churn              0
# dtype: int64

# %%
#Checking duplicated values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         CustomerID          Age      Tenure  MonthlyCharges  TotalCharges
# count  1000.000000  1000.000000  1000.00000     1000.000000   1000.000000
# mean    500.500000    44.674000    18.97300       74.391290   1404.364060
# std     288.819436     9.797741    18.89257       25.712083   1571.755048
# min       1.000000    12.000000     0.00000       30.000000      0.000000
# 25%     250.750000    38.000000     5.00000       52.357500    345.217500
# 50%     500.500000    45.000000    13.00000       74.060000    872.870000
# 75%     750.250000    51.000000    26.00000       96.102500   1900.175000
# max    1000.000000    83.000000   122.00000      119.960000  12416.250000

# %%
numeric_columns_data = df.select_dtypes(include = ["number"])

# %%
numeric_columns_data.corr()
# Out:
#                 CustomerID       Age    Tenure  MonthlyCharges  TotalCharges
# CustomerID        1.000000  0.036730 -0.018585       -0.030504     -0.027490
# Age               0.036730  1.000000  0.000472        0.006362     -0.001896
# Tenure           -0.018585  0.000472  1.000000       -0.014552      0.894868
# MonthlyCharges   -0.030504  0.006362 -0.014552        1.000000      0.304893
# TotalCharges     -0.027490 -0.001896  0.894868        0.304893      1.000000

# %%
# +1	Perfect positive relationship (both increase together)
# 0	No relationship
# -1	Perfect negative relationship (one increases, other decreases)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# Yes    883
# No     117
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Churn"].value_counts().plot(kind="pie")
plt.title("Churn (Yes/No)")
plt.ylabel("")
plt.show()

# %%
df.head(2)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
# 1           2   43   Male       0           36.67  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes
# 1     Fiber Optic           0.0         Yes   Yes

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     62.54641
# Yes    75.96077
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby(["Churn","Gender"])["MonthlyCharges"].mean()
# Out:
# Churn  Gender
# No     Female    65.091912
#        Male      59.013878
# Yes    Female    74.975064
#        Male      77.082518
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby("Churn")["Tenure"].mean()
# Out:
# Churn
# No     30.264957
# Yes    17.476784
# Name: Tenure, dtype: float64

# %%
df.head(2)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
# 1           2   43   Male       0           36.67  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes
# 1     Fiber Optic           0.0         Yes   Yes

# %%
df.groupby("Churn")["Age"].mean()
# Out:
# Churn
# No     43.487179
# Yes    44.831257
# Name: Age, dtype: float64

# %%
df.groupby("ContractType")["MonthlyCharges"].mean()
# Out:
# ContractType
# Month-to-Month    75.909198
# One-Year          73.822803
# Two-Year          71.334500
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# At the lower terms we can see that the monthly charge average decreases.

# %%
df.groupby("ContractType")["MonthlyCharges"].mean().plot(kind="bar")
plt.ylabel("Mean Price")
plt.xlabel("Contract Type")
plt.title("Contract Type Average Price")
plt.show()

# %%
df.head(2)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
# 1           2   43   Male       0           36.67  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes
# 1     Fiber Optic           0.0         Yes   Yes

# %%
plt.hist(df["MonthlyCharges"])
plt.title("Histogram of Monthly Charges")
plt.show()

# %%
plt.hist(df["Tenure"])
plt.title("Hisogram of Tenure")
# Out:
# Text(0.5, 1.0, 'Hisogram of Tenure')

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes

# %%
y = df[["Churn"]] #Response
X = df[["Age", "Gender","Tenure", "MonthlyCharges"]] #Predictors

# %%
X.head()
# Out:
#    Age  Gender  Tenure  MonthlyCharges
# 0   49    Male       4           88.35
# 1   43    Male       0           36.67
# 2   51  Female       2           63.79
# 3   60  Female       8          102.34
# 4   42    Male      32           69.01

# %%
# 1 for Female and 0 for Male
X["Gender"] = X["Gender"].apply(lambda x: 1 if x == "Female" else 0)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_14152\3648092174.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Gender"] = X["Gender"].apply(lambda x: 1 if x == "Female" else 0)

# %%
X.head()
# Out:
#    Age  Gender  Tenure  MonthlyCharges
# 0   49       0       4           88.35
# 1   43       0       0           36.67
# 2   51       1       2           63.79
# 3   60       1       8          102.34
# 4   42       0      32           69.01

# %%
type(X["Gender"][0])
# Out:
# numpy.int64

# %%
y.head()
# Out:
#   Churn
# 0   Yes
# 1   Yes
# 2   Yes
# 3   Yes
# 4   Yes

# %%
y["Churn"] = y["Churn"].apply(lambda x: 1 if x=="Yes" else 0)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_14152\2718296700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["Churn"] = y["Churn"].apply(lambda x: 1 if x=="Yes" else 0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#That is 20% of the data going to be in the testing set and 80% for the training set.

# %%
X
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-1.45513144e+00, -9.90049504e-01, -9.67388916e-01,
#         -7.72755774e-01],
#        [-6.21543791e-01, -9.90049504e-01, -9.67388916e-01,
#          1.35253297e+00],
#        [-3.08948423e-01, -9.90049504e-01,  2.05338016e+00,
#          8.35464571e-01],
#        [ 1.67082225e+00,  1.01005050e+00,  7.16318437e-01,
#         -8.75776246e-01],
#        [ 3.64694597e-03, -9.90049504e-01, -9.17868112e-01,
#          1.14491920e+00],
#        [ 3.16242315e-01, -9.90049504e-01, -7.19784894e-01,
#          5.03990305e-01],
#        [ 6.28837683e-01,  1.01005050e+00,  2.70631197e-01,
#         -6.79958708e-01],
#        [-4.13146879e-01,  1.01005050e+00,  1.01344326e+00,
#         -3.03792430e-02],
#        [ 1.07845402e-01,  1.01005050e+00, -9.17868112e-01,
#         -1.69968051e-01],
#        [ 9.41433052e-01,  1.01005050e+00, -9.17868112e-01,
#          1.68754611e+00],
#        [ 3.64694597e-03,  1.01005050e+00,  1.16200568e+00,
#         -6.14292987e-01],
#        [ 9.41433052e-01, -9.90049504e-01, -6.20743285e-01,
#          5.72408481e-01],
#        [ 1.04563151e+00,  1.01005050e+00, -8.68347307e-01,
#         -1.67792038e+00],
#        [-2.04749966e-01, -9.90049504e-01, -8.18826503e-01,
#          3.51818844e-01],
#        [-1.66352835e+00, -9.90049504e-01, -9.67388916e-01,
#          1.18699244e+00],
#        [ 3.16242315e-01, -9.90049504e-01,  7.25479786e-02,
#         -8.66339256e-01],
#         -6.09967700e-01],
#        [ 5.24639227e-01, -9.90049504e-01, -6.20743285e-01,
#         -1.35758962e-01],
#        [-1.55932990e+00,  1.01005050e+00, -2.64936304e-02,
#         -1.74686545e-01],
#        [-9.34139160e-01, -9.90049504e-01,  2.30098418e+00,
#          1.43353380e+00],
#        [-1.45513144e+00, -9.90049504e-01,  2.10290096e+00,
#         -5.00396384e-02],
#        [ 2.29601298e+00,  1.01005050e+00, -8.18826503e-01,
#         -1.00632127e+00],
#        [-1.35093299e+00,  1.01005050e+00,  1.71589588e-01,
#         -7.37760270e-01],
#        [-6.21543791e-01, -9.90049504e-01,  1.22068783e-01,
#          5.53400810e-02],
#        [ 3.12960063e+00,  1.01005050e+00, -2.74097653e-01,
#          5.05956344e-01],
#        [ 3.64694597e-03,  1.01005050e+00, -7.19784894e-01,
#          1.13744825e+00],
#        [ 9.41433052e-01, -9.90049504e-01, -5.71222480e-01,
#         -8.64373217e-01],
#        [ 4.20440771e-01, -9.90049504e-01, -9.67388916e-01,
#         -1.48918058e+00],
#        [-2.18452063e+00, -9.90049504e-01, -2.24576848e-01,
#         -1.29690192e+00],
#        [ 7.33036140e-01, -9.90049504e-01, -1.01690972e+00,
#         -1.37908237e+00],
#        [ 1.04563151e+00,  1.01005050e+00,  2.10290096e+00,
#         -6.17045442e-01],
#        [ 1.04563151e+00,  1.01005050e+00, -3.73139262e-01,
#         -8.90324939e-01],
#        [ 1.14982996e+00, -9.90049504e-01, -3.73139262e-01,
#          6.42006280e-01],
#        [-1.45513144e+00,  1.01005050e+00, -6.20743285e-01,
#          1.71729622e-01],
#        [ 2.12043858e-01,  1.01005050e+00, -8.18826503e-01,
#          1.35410580e+00],
#        [-6.21543791e-01, -9.90049504e-01,  7.25479786e-02,
#          5.80272639e-01],
#        [-9.34139160e-01,  1.01005050e+00,  2.30271741e-02,
#          9.33766549e-01],
#        [ 4.20440771e-01,  1.01005050e+00, -3.23618457e-01,
#          6.58521013e-01],
#        [ 2.12043858e-01,  1.01005050e+00,  1.95433855e+00,
#         -7.93595793e-01],
#        [ 1.77502070e+00,  1.01005050e+00,  2.70631197e-01,
#          6.85652358e-01],
#        [ 2.60860835e+00, -9.90049504e-01,  7.16318437e-01,
#         -1.74122685e+00],
#        [ 1.77502070e+00, -9.90049504e-01, -7.60144349e-02,
#         -9.29645730e-01],
#        [-1.00551510e-01, -9.90049504e-01, -8.68347307e-01,
#          1.43549984e+00]])

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions):
    print('Accuracy score on model is {}'.format(accuracy_score(y_test, predictions)))

# %%
from sklearn. model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
y_pred = log_model.predict(X_test)

# %%
y_test
# Out:
#      Churn
# 722      1
# 926      1
# 29       0
# 709      1
# 370      1
# ..     ...
# 342      0
# 677      1
# 654      1
# 767      1
# 187      1
#
# [200 rows x 1 columns]

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.86

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid = {
    "n_neighbors": [3,5,7,9],
    "weights": ["uniform","distance"],   
}

# %%
gridkn = GridSearchCV(KNeighborsClassifier(),param_grid, cv=5)

# %%
gridkn.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'n_neighbors': 9, 'weights': 'uniform'}

# %%
y_pred = gridkn.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.845

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
param_grid ={
    "C" : [0.01,0.1,0.5,1],
    "kernel": ["linear","rbf","poly"]
}

# %%
gridsvc = GridSearchCV(svm, param_grid, cv = 5)

# %%
gridsvc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
gridsvc.best_params_
# Out:
# {'C': 0.01, 'kernel': 'linear'}

# %%
y_pred = gridsvc.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.855

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid = {
    "criterion" : ["gini", "entropy"],
    "splitter": ["best", "random"],
    "max_depth": [None, 10, 20, 30],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4]
}

# %%
grid_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)

# %%
grid_tree.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_tree.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 30,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'splitter': 'random'}

# %%
y_pred = grid_tree.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.825

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model = RandomForestClassifier()

# %%
param_grid ={
    "n_estimators" : [32,64,128,256],
    "max_features" : [2,3,4],
    "bootstrap" : [True, False]
}

# %%
grid_rfc = GridSearchCV(rfc_model, param_grid, cv=5)

# %%
grid_rfc = GridSearchCV(rfc_model, param_grid, cv=5)

# %%
grid_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256]})

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 3, 'n_estimators': 128}

# %%
y_pred = grid_rfc.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.86

# %%
best_model = gridsvc.best_estimator_

# %%
joblib.dump(best_model, "model.pkl")
# Out:
# ['model.pkl']

# %%
X.columns
# Out:
# Index(['Age', 'Gender', 'Tenure', 'MonthlyCharges'], dtype='object')
